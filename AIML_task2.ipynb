# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cleaned_titanic.csv")

# %%
print(df.head())
# Out:
#    Survived  Pclass  Sex       Age  SibSp  Parch      Fare  Embarked_Q  \
# 0         0       3    1 -0.514667      1      0 -0.797316       False
# 1         1       3    0 -0.200606      0      0 -0.738993       False
# 2         1       1    0  0.506031      1      0  3.164321       False
# 3         0       3    1  0.506031      0      0 -0.728192       False
# 4         0       3    1 -0.043576      0      0 -0.692913        True
#
#    Embarked_S
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Survived    750 non-null    int64
#  1   Pclass      750 non-null    int64
#  2   Sex         750 non-null    int64
#  3   Age         750 non-null    float64
#  4   SibSp       750 non-null    int64
#  5   Parch       750 non-null    int64
#  6   Fare        750 non-null    float64
#  7   Embarked_Q  750 non-null    bool
#  8   Embarked_S  750 non-null    bool
# dtypes: bool(2), float64(2), int64(5)
# memory usage: 42.6 KB
# None

# %%
print(df.describe())
# Out:
#          Survived      Pclass         Sex           Age       SibSp  \
# count  750.000000  750.000000  750.000000  7.500000e+02  750.000000
# mean     0.325333    2.508000    0.688000  3.315866e-17    0.438667
# std      0.468812    0.711766    0.463619  1.000667e+00    0.910317
# min      0.000000    1.000000    0.000000 -2.209026e+00    0.000000
# 25%      0.000000    2.000000    0.000000 -5.146673e-01    0.000000
# 50%      0.000000    3.000000    1.000000 -4.357595e-02    0.000000
# 75%      1.000000    3.000000    1.000000  4.275154e-01    1.000000
# max      1.000000    3.000000    1.000000  4.039216e+00    5.000000
#
#             Parch          Fare
# count  750.000000  7.500000e+02
# mean     0.337333  9.473903e-18
# std      0.790172  1.000667e+00
# min      0.000000 -1.423747e+00
# 25%      0.000000 -7.415157e-01
# 50%      0.000000 -3.625941e-01
# 75%      0.000000  8.089940e-01
# max      6.000000  3.164321e+00

# %%
print(df.isnull().sum())
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Embarked_Q    0
# Embarked_S    0
# dtype: int64

# %%
df.hist(figsize=(10,8))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df["Fare"])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()

# %%
sns.pairplot(df, hue="Survived")
plt.show()

# %%
df = df.dropna()
